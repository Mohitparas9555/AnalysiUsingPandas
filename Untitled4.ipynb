# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme()
df = sns.load_dataset("tips")
sns.relplot(x='total_bill',y='tip',size='size',data=df,kind='scatter',hue='day',col='smoker',row='time')
plt.grid()
